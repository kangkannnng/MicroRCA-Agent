# %%
import os
import pandas as pd
import json

# 输入目录路径
input_dir = "data/2025-06-06"
output_dir = "test_data"

# 确保输出目录存在
os.makedirs(output_dir, exist_ok=True)

# 指定时间范围
start_time = "2025-06-05T16:10:02Z"
end_time = "2025-06-05T16:31:02Z"

# 转换时间为 pandas.Timestamp
start_time = pd.Timestamp(start_time)
end_time = pd.Timestamp(end_time)

# 处理 log 文件
def process_log_file(file_path, output_path):
    try:
        df = pd.read_parquet(file_path)
        if '@timestamp' in df.columns:
            df['@timestamp'] = pd.to_datetime(df['@timestamp'])
            filtered_df = df[(df['@timestamp'] >= start_time) & (df['@timestamp'] <= end_time)]
            if not filtered_df.empty:
                filtered_df.to_json(output_path, orient="records", lines=True)
                print(f"Filtered log data saved to {output_path}")
    except Exception as e:
        print(f"Error processing log file {file_path}: {e}")

# 处理 trace 文件
def process_trace_file(file_path, output_path):
    try:
        df = pd.read_parquet(file_path)
        if 'startTimeMillis' in df.columns:
            filtered_df = df[(df['startTimeMillis'] >= start_time.value // 10**6) & 
                             (df['startTimeMillis'] <= end_time.value // 10**6)]
            if not filtered_df.empty:
                filtered_df.to_json(output_path, orient="records", lines=True)
                print(f"Filtered trace data saved to {output_path}")
    except Exception as e:
        print(f"Error processing trace file {file_path}: {e}")

# 处理 metric 文件
def process_metric_file(file_path, output_path):
    try:
        df = pd.read_parquet(file_path)
        if 'time' in df.columns:
            df['time'] = pd.to_datetime(df['time'])
            filtered_df = df[(df['time'] >= start_time) & (df['time'] <= end_time)]
            if not filtered_df.empty:
                filtered_df.to_json(output_path, orient="records", lines=True)
                print(f"Filtered metric data saved to {output_path}")
    except Exception as e:
        print(f"Error processing metric file {file_path}: {e}")

# 遍历目录中的所有 Parquet 文件
for root, _, files in os.walk(input_dir):
    for file in files:
        if file.endswith(".parquet"):
            input_file_path = os.path.join(root, file)
            relative_path = os.path.relpath(root, input_dir)
            output_subdir = os.path.join(output_dir, relative_path)
            os.makedirs(output_subdir, exist_ok=True)
            output_file_path = os.path.join(output_subdir, f"{os.path.splitext(file)[0]}.json")

            # 根据目录分类处理
            if "log-parquet" in root:
                process_log_file(input_file_path, output_file_path)
            elif "trace-parquet" in root:
                process_trace_file(input_file_path, output_file_path)
            elif "metric-parquet" in root:
                process_metric_file(input_file_path, output_file_path)
# Out:
# Filtered trace data saved to test_data/trace-parquet/trace_jaeger-span_2025-06-06_00-00-00.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_store_low_space_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_learner_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_memory_usage_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_grpc_qps_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_region_health_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_qps_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_raft_propose_wait_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_storage_capacity_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_cpu_usage_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_store_down_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_snapshot_apply_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_witness_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_store_size_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_abnormal_region_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_storage_used_ratio_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_threadpool_readpool_cpu_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_storage_size_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_capacity_size_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_leader_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_server_is_up_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_raft_apply_wait_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_region_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_rocksdb_write_stall_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_store_slow_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_read_mbps_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_store_unhealth_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_store_up_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_pd_leader_primary_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_region_pending_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_available_size_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_io_util_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/other/infra_tikv_write_wal_mbps_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_pod/infra_pod_pod_processes_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_pod/infra_pod_pod_network_receive_packets_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_pod/infra_pod_pod_network_transmit_bytes_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_pod/infra_pod_pod_fs_writes_bytes_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_pod/infra_pod_pod_network_receive_bytes_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_pod/infra_pod_pod_cpu_usage_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_pod/infra_pod_pod_fs_reads_bytes_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_pod/infra_pod_pod_network_transmit_packets_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_pod/infra_pod_pod_memory_working_set_bytes_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_memory_MemTotal_bytes_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_disk_read_bytes_total_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_disk_read_time_seconds_total_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_network_transmit_bytes_total_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_network_receive_bytes_total_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_sockstat_TCP_inuse_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_filesystem_size_bytes_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_disk_write_time_seconds_total_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_network_transmit_packets_total_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_memory_MemAvailable_bytes_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_filesystem_usage_rate_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_disk_written_bytes_total_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_filesystem_free_bytes_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_memory_usage_rate_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_cpu_usage_rate_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_node/infra_node_node_network_receive_packets_total_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_duration_95th_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_block_cache_size_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_duration_avg_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_duration_99th_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_memory_usage_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_qps_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_cpu_usage_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_connection_count_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_transaction_retry_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_top_sql_cpu_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_uptime_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_server_is_up_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/infra/infra_tidb/infra_tidb_failed_query_ops_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod_ns_hipstershop_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_recommendationservice_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_frontend_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_cartservice_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_paymentservice_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_emailservice_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_redis-cart_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_shippingservice_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_currencyservice_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_adservice_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_productcatalogservice_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/service/service_checkoutservice_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_emailservice-2_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_productcatalogservice-0_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_frontend-2_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_adservice-2_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_paymentservice-2_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_productcatalogservice-1_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_cartservice-2_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_emailservice-1_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_recommendationservice-0_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_frontend-1_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_shippingservice-2_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_shippingservice-0_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_adservice-1_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_currencyservice-0_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_cartservice-0_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_productcatalogservice-2_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_frontend-0_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_paymentservice-0_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_emailservice-0_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_shippingservice-1_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_cartservice-1_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_checkoutservice-2_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_redis-cart-0_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_adservice-0_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_currencyservice-2_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_paymentservice-1_2025-06-06.json
# Filtered metric data saved to test_data/metric-parquet/apm/pod/pod_currencyservice-1_2025-06-06.json
# Filtered log data saved to test_data/log-parquet/log_filebeat-server_2025-06-06_00-00-00.json
